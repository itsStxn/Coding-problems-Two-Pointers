# %% [markdown]
# # Valid Palindrome

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.isPalindrome(s = "A man, a plan, a canal: Panama")
# Out:
# True

# %% [markdown]
# ## Test 2

# %%
task.isPalindrome(s = "race a car")
# Out:
# False

# %% [markdown]
# ## Test 3

# %%
task.isPalindrome(s = " ")
# Out:
# True
