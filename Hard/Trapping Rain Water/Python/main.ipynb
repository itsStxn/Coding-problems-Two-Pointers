# %% [markdown]
# # Trapping Rain Water

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.trap(height = [0,1,0,2,1,0,1,3,2,1,2,1])
# Out:
# 6

# %% [markdown]
# ## Test 2

# %%
task.trap(height = [4,2,0,3,2,5])
# Out:
# 9
