# %% [markdown]
# # 3Sum

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.threeSum(nums = [-1,0,1,2,-1,-4])
# Out:
# [[-1, -1, 2], [-1, 0, 1]]

# %% [markdown]
# ## Test 2

# %%
task.threeSum(nums = [0,1,1])
# Out:
# []

# %% [markdown]
# ## Test 3

# %%
task.threeSum(nums = [0,0,0])
# Out:
# [[0, 0, 0]]
