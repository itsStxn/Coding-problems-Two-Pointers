# %% [markdown]
# # Container With Most Water

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.maxArea(height = [1,8,6,2,5,4,8,3,7])
# Out:
# 49

# %% [markdown]
# ## Test 2

# %%
task.maxArea(height = [1,1])
# Out:
# 1
