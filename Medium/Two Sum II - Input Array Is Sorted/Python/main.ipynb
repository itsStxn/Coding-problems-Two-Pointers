# %% [markdown]
# # Two Sum II - Input array is sorted

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.twoSum(numbers = [2,7,11,15], target = 9)
# Out:
# [1, 2]

# %% [markdown]
# ## Test 2

# %%
task.twoSum(numbers = [2,3,4], target = 6)
# Out:
# [1, 3]

# %% [markdown]
# ## Test 3

# %%
task.twoSum(numbers = [-1,0], target = -1)
# Out:
# [1, 2]
